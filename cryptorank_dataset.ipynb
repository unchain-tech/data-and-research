# %%
from dotenv import load_dotenv
import os
import requests
from bs4 import BeautifulSoup
import random
from decimal import Decimal
from re import sub
import pandas as pd
from tabulate import tabulate
import dateparser
import numpy as np

# %%
dotenv_path = os.path.join(os.getcwd(), '.env')
load_dotenv(dotenv_path)
cr_api = os.getenv("CRYPTORANK_API")

# %%
# get a list of user agents for randomization
userAgents = requests.get("https://raw.githubusercontent.com/DavidWittman/requests-random-user-agent/master/requests_random_user_agent/useragents.txt").text.split("\n")

# get a list of cryptocurrencies data
url = "https://api.cryptorank.io/v1/currencies"
p = {
    'api_key': cr_api,
    'limit': 500,
}
currencies = requests.get(url, params=p).json()["data"]

# %%
# convert to slug
currencySlugs = [currencies[i]["slug"] for i in range(len(currencies))]
currencySlugs
# Out:
# ['bitcoin',
#  'ethereum',
#  'tether',
#  'bnb',
#  'usdcoin',
#  'ripple',
#  'solana',
#  'cardano',
#  'luna',
#  'terra-usd',
#  'binance-usd',
#  'dogecoin',
#  'polkadot',
#  'avalanche',
#  'lido-staked-ether',
#  'wrapped-bitcoin',
#  'shiba-inu',
#  'tron',
#  'multicollateraldai',
#  'near-protocol',
#  'matic-network',
#  'litecoin',
#  'crypto-com-cro',
#  'bitcoin-cash',
#  'leobitfinex',
#  'algorand',
#  'chainlink',
#  'ftx-token',
#  'cosmos',
#  'okb',
#  'stellar',
#  'monero',
#  'ethereum-classic',
#  'uniswap',
#  'ape-coin',
#  'bit-dao',
#  'vechainthor',
#  'magic-internet-money',
#  'internet-computer',
#  'hedera-hashgraph',
#  'frax_uniswap',
#  'filecoin',
#  'elrond-gold',
#  'sandbox',
#  'axie-infinity',
#  'tezos',
#  'defichain',
#  'the-graph',
#  'theta-token',
#  'pancakeswap',
#  'decentraland',
#  'eos',
#  'bittorrent-new',
#  'aave',
#  'thor-chain',
#  'fantom',
#  'klaytn',
#  'stepn',
#  'kucoin-shares',
#  'flow',
#  'zcash',
#  'chain-new',
#  'helium-hnt',
#  'huobi-token',
#  'frax-share',
#  'bitcoin-sv',
#  'iota',
#  'convex-finance',
#  'waves',
#  'ecash',
#  'true-usd',
#  'osmosis',
#  'neo',
#  'quant',
#  'zilliqa',
#  'radix-protocol',
#  'maker',
#  'nexo',
#  'kusama',
#  'arweave',
#  'gala',
#  'paxos-standard-token',
#  'synthetix',
#  'lido-dao',
#  'gatechain-token',
#  'neutrino-dollar',
#  'curve',
#  'enjin-coin',
#  'dash',
#  'chiliz',
#  'harmony',
#  'amp',
#  'basic-attention-token',
#  'blockstack',
#  'loopring',
#  'maiar-dex',
#  'celsius',
#  'mina-protocol',
#  'celo',
#  'decred',
#  'xdc-network',
#  'nem',
#  'evmos',
#  'holo',
#  'compound',
#  'kava',
#  'pax-gold',
#  'theta-fuel',
#  'synapse-new',
#  'fei-usd',
#  'yearn-finance',
#  'secret',
#  'anchor-protocol',
#  '1inch',
#  'kadena',
#  'audius',
#  'gnosis-gno',
#  'qtum',
#  'glimmer',
#  '0x',
#  'oasis-network',
#  'omisego',
#  'livepeer',
#  'icon',
#  'marinade',
#  'juno-network',
#  'serum',
#  'iostoken',
#  'iotex',
#  'bancor',
#  'just',
#  'liquity-usd',
#  'tether-gold',
#  'bora',
#  'bitcoin-gold',
#  'skale',
#  'rocket-pool',
#  'ankr-network',
#  'ecomi',
#  'symbol',
#  'astar-network',
#  'songbird',
#  'ethereum-name-service',
#  'dogelon',
#  'swipe',
#  'ravencoin',
#  'sushi',
#  'constellation',
#  'okexchain',
#  'zencash',
#  'siacoin',
#  'dydx',
#  'everscale',
#  'ontology',
#  'bitgert',
#  'apenft',
#  'wax',
#  'bitkub-coin',
#  'uma',
#  'velas',
#  'swissborg',
#  'project-galaxy',
#  'nucypher',
#  'looksrare',
#  'golem-glm',
#  'rally',
#  'immutable-x',
#  'render-token',
#  'olympus',
#  'husd',
#  'titan',
#  'astroport',
#  'flux-new',
#  'voyager-token',
#  'trust-wallet-token',
#  'aleph-zero',
#  'mai',
#  'mineplex',
#  'yusd-stablecoin',
#  'nervos',
#  'illuvium',
#  'small-love-potion',
#  'safemoon-v2',
#  'casper',
#  'hive-blockchain',
#  'renbtc',
#  'baby-doge-coin',
#  'spell-token',
#  'digibyte',
#  'dao-token',
#  'republic-protocol',
#  'polymath-network',
#  'radio-caca',
#  'decentralized-social',
#  'pirate-chain',
#  'playdapp',
#  'tenset',
#  'lido-for-solana',
#  'mxc',
#  'usdd',
#  'biswap',
#  'vvs-finance',
#  'mobox',
#  'lisk',
#  'telcoin',
#  'wink-token',
#  'ceek-vr',
#  'nano',
#  'e-radix',
#  'syscoin',
#  'binaryx',
#  'gmx',
#  'tomb',
#  'wazirx',
#  'coinex-token',
#  'zipmex',
#  'mobilecoin',
#  'gemini-dollar',
#  'injective-protocol',
#  'persistence',
#  'mxtoken',
#  'keep-network',
#  'medibloc',
#  'anyswap',
#  'chia-network',
#  'coin-98',
#  'multichain',
#  'coti',
#  'benqi-liquid-staked-avax',
#  'vulcan-forged-pyr',
#  'status',
#  'functionx',
#  'dent',
#  'holoride',
#  'joe',
#  'chromia',
#  'constitutiondao',
#  'orbs',
#  'origin-protocol',
#  'eurt',
#  'pundi-x-new',
#  'aurora-evm',
#  'celer-network',
#  'telos',
#  'energy-web-token',
#  'ergo',
#  'conflux-network',
#  'fetch-ai',
#  'usdx-kava',
#  'api-3',
#  'mask-network',
#  'xyo-network',
#  'sifchain',
#  'civic',
#  'power-ledger',
#  'merit-circle',
#  'c2x',
#  'tribe-fei-protocol',
#  'weway',
#  'ardor',
#  'locus-chain-new',
#  'zoidpay',
#  'xdb',
#  'ultra',
#  'raydium',
#  'ocean-protocol',
#  'steem',
#  'perpetual-protocol',
#  'xsgd',
#  'divi',
#  'cratos',
#  'x-sushi',
#  'milk',
#  'wootrade',
#  'league-of-kingdoms',
#  'railgun',
#  'tokemak',
#  'klever',
#  'crypto-com-mco',
#  'mirror-protocol',
#  'stepapp',
#  'dopex',
#  'maple-finance',
#  'cartesi',
#  'radicle',
#  'my-neighbor-alice',
#  'lukso',
#  'reserve-rights-token',
#  'mdex',
#  'vethor',
#  'balancer',
#  'hxro',
#  'sun-token-new',
#  'dero',
#  'moonriver',
#  'request-network',
#  'humanscape',
#  'metisdao',
#  'stasis-eurs',
#  'defi-kingdoms',
#  'bitmax-token',
#  'metahero',
#  'storm',
#  'ellipsis',
#  'creditcoin',
#  'origintrail',
#  'sperax',
#  'verge',
#  'kyber-network',
#  'mines-of-dalarnia',
#  'ark',
#  'floki-inu-new',
#  'synthetix-usd',
#  'numeraire',
#  'aragon',
#  'band-protocol',
#  'storj',
#  'alpha-finance-lab',
#  'biconomy',
#  'boba-network',
#  'ronin',
#  'reef',
#  'bifrost',
#  'goldfinch-finance',
#  'thetruth',
#  'prometeus',
#  'stratis',
#  'kava-swap',
#  'funfair',
#  'metadium',
#  'orchid-labs',
#  'metal',
#  'rari-governance-token',
#  'liquity',
#  'dawn-protocol',
#  'stp-network',
#  'aavegotchi',
#  'quarkchain',
#  'super-farm',
#  'keep3rv1',
#  'hoo-token',
#  'gensokishi',
#  'aelf',
#  'mango-markets',
#  'centrality',
#  'strike',
#  'alchemy-pay',
#  'yield-guild-games',
#  'world-mobile-token',
#  'nkn',
#  'rif-token',
#  'bakeryswap',
#  'ssv-network',
#  'bitcoin-standard-hashrate-token',
#  'rlc',
#  'x-2-y-2',
#  'propy',
#  'origin-dollar',
#  'yoshi-exchange',
#  'trusttoken',
#  'beta-finance',
#  'singularitynet',
#  'dopex-rebate-token',
#  'gpex',
#  'kiltprotocol',
#  'ampleforth',
#  'veritaseum',
#  'venus',
#  'bloktopia',
#  'cult-dao',
#  'coinmetro-token',
#  'hermez-network',
#  'polkastarter',
#  'utrust',
#  'shiba-predator',
#  'tomb-shares',
#  'proton',
#  'dodo',
#  'mm-finance',
#  'qredo',
#  'deversifi',
#  'everipedia',
#  'dusk',
#  'alien-worlds',
#  'sologenic',
#  'electroneum',
#  'platon-network',
#  'wonderland',
#  'tomochain',
#  'kishu-inu',
#  'xcad-network',
#  'beefyfinance',
#  'e-money',
#  'torn',
#  'hydra',
#  'fegtoken',
#  'kardiachain',
#  'ageur',
#  'luffy',
#  'mass-vehicle-ledger',
#  'jasmy',
#  'augur',
#  'idex',
#  'gxchain',
#  'yooshi',
#  'star-link',
#  'orionprotocol',
#  'banana-token',
#  'auction',
#  'aioz-network',
#  'itheum',
#  'hunt',
#  'blox',
#  'shapeshift-fox-token',
#  'covalent-new',
#  'cvault-finance',
#  'thundercore',
#  'seedify-fund',
#  'certi-k',
#  'wrappednxm',
#  'hathor',
#  'victoria-vr',
#  'cocos-bcx-token',
#  'aergo',
#  'rmrk',
#  'dola-usd-stablecoin',
#  'badger-dao',
#  'celo-dollar',
#  'alchemix',
#  'safepal',
#  'pond_uniswap',
#  'alpaca-finance',
#  'dvision-network',
#  'adventure-gold',
#  'aurory',
#  'marketpeak',
#  'xmon',
#  'wanchain',
#  'nest-protocol',
#  'clover',
#  'wrapped-centrifuge',
#  'gitcoin',
#  'nominex',
#  'pylon-protocol',
#  'district0x',
#  'defi-pulse-index',
#  'melon',
#  'deapcoin',
#  'efforce',
#  'allianceblock',
#  'automata-network',
#  'neutrino-system-base-token',
#  'unibright',
#  'karura',
#  'klima-dao',
#  'quickswap',
#  'mstable-usd',
#  'lto-network',
#  'concordium',
#  'travala',
#  'unifty',
#  'handshake',
#  'acala-network',
#  'linear',
#  'carry-protocol',
#  'stargaze',
#  'mainframe',
#  'loom-network',
#  'gst',
#  'mwc',
#  'toucan-protocol-base-carbon-tonne',
#  'uquid-coin',
#  'elastos',
#  'keeperdao',
#  'bxmi-token',
#  'gains-network',
#  'alpha-quark-token',
#  'avinoc',
#  'magic',
#  'rakon',
#  'bonfida',
#  'aleph_switcheo',
#  'bitrue-coin',
#  'verasity',
#  'vai-token',
#  'flamingo',
#  'genopets',
#  'socean-staked-sol',
#  'alpine-f-1-team-fan-token',
#  'bitmart-token',
#  'lcx',
#  'swarm',
#  'superrare',
#  'voxies',
#  'komodo',
#  'monacoin',
#  'benqi',
#  'bitcoin-diamond',
#  'gas',
#  'derivadao']

# %%
tokenSaleLink = "https://cryptorank.io/ico/"
master_dict = []

for asset in currencySlugs:

    # get asset tokenomics page with randomized user agent
    scrapeLink = tokenSaleLink + asset
    r = requests.get(scrapeLink, headers={"User-Agent": random.choice(userAgents)})

    d = {}
    d["asset"] = asset

    # if page exists
    if r.status_code == 200:
        print(asset + ": DATA GET SUCCESS")
        assetSoup = BeautifulSoup(r.text, "html.parser")
        
        # find allocation component
        tokenomics_component = assetSoup.find_all("p", {"class": "styled__TokenomicsValue-sc-3338go-2 dCnyxZ"})
        # separate allocation component
        for i in tokenomics_component:
            if ":" in i.text:
                element = i.text.split("(")[0][:-1].split(":")

                colName = element[0]
                colValue = Decimal(sub(r'[^\d.]', '', element[1]))
            else:
                colName = "Total Raised"
                colValue = Decimal(sub(r'[^\d.]', '', i.text))

            d[colName] = colValue

        # find rounds component
        rounds_component = assetSoup.find_all("div", {"class": "styled__IcoRoundContainer-sc-19xalay-0 gcmMjD"})

        # for each round, identify the round date (for reordering)
        round_Dates = []
        for i in range(len(rounds_component)):
            try:
                round_date = rounds_component[i].find("span", {"class": "info-text__date"}).text
                # if range, use end month
                if "—" in round_date:
                    end_date = dateparser.parse(round_date.split("—")[-1]).strftime("%Y-%m")
                # if useless, replace with nan
                elif "in the Past" in end_date:
                    end_date = np.nan
                # if no range, keep as is
                else:
                    end_date = dateparser.parse(round_date).strftime("%Y-%m")
                round_Dates.append(end_date)
            except:
                end_date = np.nan
        # reorder rounds by index
        roundOrder = np.argsort(np.array(round_Dates))


        roundCount = 0
        for i in roundOrder:
            roundCount += 1
            round_type = rounds_component[i].find("span", {"class": "info-text__type"}).text.split("is ended")[0]
            round_date = rounds_component[i].find("span", {"class": "info-text__date"}).text
            try:
                # if range, use end month
                if "—" in round_date:
                    end_date = dateparser.parse(round_date.split("—")[-1]).strftime("%Y-%m")
                # if useless, replace with nan
                elif "in the Past" in end_date:
                    end_date = "2000-01"
                # if no range, keep as is
                else:
                    end_date = dateparser.parse(round_date).strftime("%Y-%m")
            except:
                end_date = np.nan

            d[f"R{str(roundCount)} type"] = round_type
            d[f"R{str(roundCount)} date"] = end_date

            round_detail = rounds_component[i].find_all("div", {"class": "styled__IcoColumn-sc-19xalay-4 kElqSx"})
            for j in round_detail:
                try:
                    try:
                        colName = j.find("h4", {"class": "styled__HeaderColumn-sc-19xalay-3 iOiuVh"}).text
                        colValue = j.find("div", {"class": "styled__ContentColumn-sc-1g6ocb2-1 cltaKE"}).find("p").text
                        d[f"R{str(roundCount)} {colName}"] = colValue

                    except: # lockup period has a different div class
                            colName = j.find("h4", {"class": "styled__HeaderColumn-sc-19xalay-3 iOiuVh"}).text
                            colValue = j.find("div", {"class": "styled__ContentColumn-sc-1g6ocb2-1 styled__LongDescriptionColumn-sc-1g6ocb2-2 cltaKE bGlSHw"}).find("p").text
                            d[f"R{str(roundCount)} {colName}"] = colValue
                except:
                    pass

        master_dict.append(d)
        
    # if page doesn't  exist
    else:
        print(asset + ": NO DATA")

raw_df = pd.DataFrame(master_dict)
# Out:
# bitcoin: NO DATA
# ethereum: NO DATA
# tether: NO DATA
# bnb: NO DATA
# usdcoin: NO DATA
# ripple: NO DATA
# solana: DATA GET SUCCESS
# /Users/shohihara/Developer/shiftbase/UNCHAIN/data_and_research/messari_dataset/venv/lib/python3.9/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
# cardano: DATA GET SUCCESS
# luna: DATA GET SUCCESS
# terra-usd: NO DATA
# binance-usd: NO DATA
# dogecoin: NO DATA
# polkadot: NO DATA
# avalanche: DATA GET SUCCESS
# lido-staked-ether: NO DATA
# wrapped-bitcoin: NO DATA
# shiba-inu: NO DATA
# tron: DATA GET SUCCESS
# multicollateraldai: NO DATA
# near-protocol: DATA GET SUCCESS
# matic-network: DATA GET SUCCESS
# litecoin: NO DATA
# crypto-com-cro: NO DATA
# bitcoin-cash: NO DATA
# leobitfinex: DATA GET SUCCESS
# algorand: DATA GET SUCCESS
# chainlink: DATA GET SUCCESS
# ftx-token: NO DATA
# cosmos: DATA GET SUCCESS
# okb: NO DATA
# stellar: NO DATA
# monero: NO DATA
# ethereum-classic: NO DATA
# uniswap: NO DATA
# ape-coin: NO DATA
# bit-dao: DATA GET SUCCESS
# vechainthor: NO DATA
# magic-internet-money: NO DATA
# internet-computer: NO DATA
# hedera-hashgraph: DATA GET SUCCESS
# frax_uniswap: NO DATA
# filecoin: DATA GET SUCCESS
# elrond-gold: DATA GET SUCCESS
# sandbox: DATA GET SUCCESS
# axie-infinity: DATA GET SUCCESS
# tezos: DATA GET SUCCESS
# defichain: NO DATA
# the-graph: DATA GET SUCCESS
# theta-token: DATA GET SUCCESS
# pancakeswap: NO DATA
# decentraland: DATA GET SUCCESS
# eos: DATA GET SUCCESS
# bittorrent-new: DATA GET SUCCESS
# aave: NO DATA
# thor-chain: DATA GET SUCCESS
# fantom: DATA GET SUCCESS
# klaytn: DATA GET SUCCESS
# stepn: DATA GET SUCCESS
# kucoin-shares: NO DATA
# flow: DATA GET SUCCESS
# zcash: NO DATA
# chain-new: NO DATA
# helium-hnt: NO DATA
# huobi-token: DATA GET SUCCESS
# frax-share: NO DATA
# bitcoin-sv: NO DATA
# iota: NO DATA
# convex-finance: NO DATA
# waves: DATA GET SUCCESS
# ecash: NO DATA
# true-usd: NO DATA
# osmosis: NO DATA
# neo: NO DATA
# quant: DATA GET SUCCESS
# zilliqa: DATA GET SUCCESS
# radix-protocol: NO DATA
# maker: NO DATA
# nexo: DATA GET SUCCESS
# kusama: NO DATA
# arweave: DATA GET SUCCESS
# gala: NO DATA
# paxos-standard-token: NO DATA
# synthetix: DATA GET SUCCESS
# lido-dao: NO DATA
# gatechain-token: DATA GET SUCCESS
# neutrino-dollar: NO DATA
# curve: NO DATA
# enjin-coin: DATA GET SUCCESS
# dash: NO DATA
# chiliz: NO DATA
# harmony: DATA GET SUCCESS
# amp: NO DATA
# basic-attention-token: DATA GET SUCCESS
# blockstack: DATA GET SUCCESS
# loopring: DATA GET SUCCESS
# maiar-dex: NO DATA
# celsius: DATA GET SUCCESS
# mina-protocol: DATA GET SUCCESS
# celo: DATA GET SUCCESS
# decred: NO DATA
# xdc-network: NO DATA
# nem: NO DATA
# evmos: NO DATA
# holo: DATA GET SUCCESS
# compound: NO DATA
# kava: DATA GET SUCCESS
# pax-gold: NO DATA
# theta-fuel: NO DATA
# synapse-new: NO DATA
# fei-usd: NO DATA
# yearn-finance: NO DATA
# secret: NO DATA
# anchor-protocol: DATA GET SUCCESS
# 1inch: NO DATA
# kadena: DATA GET SUCCESS
# audius: NO DATA
# gnosis-gno: DATA GET SUCCESS
# qtum: NO DATA
# glimmer: DATA GET SUCCESS
# 0x: DATA GET SUCCESS
# oasis-network: DATA GET SUCCESS
# omisego: DATA GET SUCCESS
# livepeer: NO DATA
# icon: DATA GET SUCCESS
# marinade: NO DATA
# juno-network: NO DATA
# serum: DATA GET SUCCESS
# iostoken: DATA GET SUCCESS
# iotex: DATA GET SUCCESS
# bancor: DATA GET SUCCESS
# just: DATA GET SUCCESS
# liquity-usd: NO DATA
# tether-gold: NO DATA
# bora: NO DATA
# bitcoin-gold: NO DATA
# skale: DATA GET SUCCESS
# rocket-pool: NO DATA
# ankr-network: DATA GET SUCCESS
# ecomi: DATA GET SUCCESS
# symbol: NO DATA
# astar-network: DATA GET SUCCESS
# songbird: NO DATA
# ethereum-name-service: NO DATA
# dogelon: NO DATA
# swipe: DATA GET SUCCESS
# ravencoin: NO DATA
# sushi: NO DATA
# constellation: DATA GET SUCCESS
# okexchain: NO DATA
# zencash: NO DATA
# siacoin: NO DATA
# dydx: NO DATA
# everscale: NO DATA
# ontology: DATA GET SUCCESS
# bitgert: NO DATA
# apenft: DATA GET SUCCESS
# wax: DATA GET SUCCESS
# bitkub-coin: NO DATA
# uma: NO DATA
# velas: NO DATA
# swissborg: DATA GET SUCCESS
# project-galaxy: DATA GET SUCCESS
# nucypher: DATA GET SUCCESS
# looksrare: NO DATA
# golem-glm: NO DATA
# rally: DATA GET SUCCESS
# immutable-x: DATA GET SUCCESS
# render-token: NO DATA
# olympus: NO DATA
# husd: NO DATA
# titan: NO DATA
# astroport: NO DATA
# flux-new: NO DATA
# voyager-token: NO DATA
# trust-wallet-token: NO DATA
# aleph-zero: DATA GET SUCCESS
# mai: NO DATA
# mineplex: NO DATA
# yusd-stablecoin: NO DATA
# nervos: DATA GET SUCCESS
# illuvium: DATA GET SUCCESS
# small-love-potion: NO DATA
# safemoon-v2: NO DATA
# casper: DATA GET SUCCESS
# hive-blockchain: NO DATA
# renbtc: NO DATA
# baby-doge-coin: NO DATA
# spell-token: NO DATA
# digibyte: NO DATA
# dao-token: DATA GET SUCCESS
# republic-protocol: DATA GET SUCCESS
# polymath-network: DATA GET SUCCESS
# radio-caca: DATA GET SUCCESS
# decentralized-social: NO DATA
# pirate-chain: NO DATA
# playdapp: NO DATA
# tenset: NO DATA
# lido-for-solana: NO DATA
# mxc: DATA GET SUCCESS
# usdd: NO DATA
# biswap: NO DATA
# vvs-finance: NO DATA
# mobox: NO DATA
# lisk: NO DATA
# telcoin: DATA GET SUCCESS
# wink-token: DATA GET SUCCESS
# ceek-vr: NO DATA
# nano: NO DATA
# e-radix: DATA GET SUCCESS
# syscoin: NO DATA
# binaryx: NO DATA
# gmx: NO DATA
# tomb: NO DATA
# wazirx: DATA GET SUCCESS
# coinex-token: NO DATA
# zipmex: NO DATA
# mobilecoin: NO DATA
# gemini-dollar: NO DATA
# injective-protocol: DATA GET SUCCESS
# persistence: DATA GET SUCCESS
# mxtoken: NO DATA
# keep-network: DATA GET SUCCESS
# medibloc: DATA GET SUCCESS
# anyswap: NO DATA
# chia-network: NO DATA
# coin-98: DATA GET SUCCESS
# multichain: NO DATA
# coti: DATA GET SUCCESS
# benqi-liquid-staked-avax: NO DATA
# vulcan-forged-pyr: NO DATA
# status: DATA GET SUCCESS
# functionx: NO DATA
# dent: DATA GET SUCCESS
# holoride: DATA GET SUCCESS
# joe: NO DATA
# chromia: DATA GET SUCCESS
# constitutiondao: NO DATA
# orbs: DATA GET SUCCESS
# origin-protocol: DATA GET SUCCESS
# eurt: NO DATA
# pundi-x-new: NO DATA
# aurora-evm: DATA GET SUCCESS
# celer-network: DATA GET SUCCESS
# telos: NO DATA
# energy-web-token: NO DATA
# ergo: NO DATA
# conflux-network: NO DATA
# fetch-ai: DATA GET SUCCESS
# usdx-kava: NO DATA
# api-3: DATA GET SUCCESS
# mask-network: DATA GET SUCCESS
# xyo-network: DATA GET SUCCESS
# sifchain: DATA GET SUCCESS
# civic: DATA GET SUCCESS
# power-ledger: DATA GET SUCCESS
# merit-circle: NO DATA
# c2x: DATA GET SUCCESS
# tribe-fei-protocol: DATA GET SUCCESS
# weway: DATA GET SUCCESS
# ardor: NO DATA
# locus-chain-new: NO DATA
# zoidpay: NO DATA
# xdb: NO DATA
# ultra: DATA GET SUCCESS
# raydium: NO DATA
# ocean-protocol: DATA GET SUCCESS
# steem: NO DATA
# perpetual-protocol: DATA GET SUCCESS
# xsgd: NO DATA
# divi: NO DATA
# cratos: NO DATA
# x-sushi: NO DATA
# milk: DATA GET SUCCESS
# wootrade: NO DATA
# league-of-kingdoms: DATA GET SUCCESS
# railgun: NO DATA
# tokemak: NO DATA
# klever: NO DATA
# crypto-com-mco: DATA GET SUCCESS
# mirror-protocol: NO DATA
# stepapp: DATA GET SUCCESS
# dopex: NO DATA
# maple-finance: DATA GET SUCCESS
# cartesi: DATA GET SUCCESS
# radicle: NO DATA
# my-neighbor-alice: DATA GET SUCCESS
# lukso: DATA GET SUCCESS
# reserve-rights-token: DATA GET SUCCESS
# mdex: NO DATA
# vethor: NO DATA
# balancer: NO DATA
# hxro: DATA GET SUCCESS
# sun-token-new: NO DATA
# dero: NO DATA
# moonriver: NO DATA
# request-network: DATA GET SUCCESS
# humanscape: NO DATA
# metisdao: DATA GET SUCCESS
# stasis-eurs: NO DATA
# defi-kingdoms: NO DATA
# bitmax-token: DATA GET SUCCESS
# metahero: NO DATA
# storm: DATA GET SUCCESS
# ellipsis: NO DATA
# creditcoin: NO DATA
# origintrail: DATA GET SUCCESS
# sperax: DATA GET SUCCESS
# verge: NO DATA
# kyber-network: DATA GET SUCCESS
# mines-of-dalarnia: DATA GET SUCCESS
# ark: NO DATA
# floki-inu-new: DATA GET SUCCESS
# synthetix-usd: NO DATA
# numeraire: NO DATA
# aragon: NO DATA
# band-protocol: DATA GET SUCCESS
# storj: DATA GET SUCCESS
# alpha-finance-lab: DATA GET SUCCESS
# biconomy: DATA GET SUCCESS
# boba-network: NO DATA
# ronin: NO DATA
# reef: DATA GET SUCCESS
# bifrost: DATA GET SUCCESS
# goldfinch-finance: DATA GET SUCCESS
# thetruth: NO DATA
# prometeus: DATA GET SUCCESS
# stratis: NO DATA
# kava-swap: NO DATA
# funfair: NO DATA
# metadium: DATA GET SUCCESS
# orchid-labs: DATA GET SUCCESS
# metal: NO DATA
# rari-governance-token: NO DATA
# liquity: NO DATA
# dawn-protocol: NO DATA
# stp-network: NO DATA
# aavegotchi: NO DATA
# quarkchain: DATA GET SUCCESS
# super-farm: DATA GET SUCCESS
# keep3rv1: NO DATA
# hoo-token: NO DATA
# gensokishi: DATA GET SUCCESS
# aelf: DATA GET SUCCESS
# mango-markets: DATA GET SUCCESS
# centrality: NO DATA
# strike: NO DATA
# alchemy-pay: NO DATA
# yield-guild-games: DATA GET SUCCESS
# world-mobile-token: NO DATA
# nkn: DATA GET SUCCESS
# rif-token: NO DATA
# bakeryswap: NO DATA
# ssv-network: NO DATA
# bitcoin-standard-hashrate-token: NO DATA
# rlc: NO DATA
# x-2-y-2: NO DATA
# propy: NO DATA
# origin-dollar: NO DATA
# yoshi-exchange: NO DATA
# trusttoken: NO DATA
# beta-finance: DATA GET SUCCESS
# singularitynet: DATA GET SUCCESS
# dopex-rebate-token: NO DATA
# gpex: NO DATA
# kiltprotocol: NO DATA
# ampleforth: DATA GET SUCCESS
# veritaseum: NO DATA
# venus: NO DATA
# bloktopia: DATA GET SUCCESS
# cult-dao: NO DATA
# coinmetro-token: NO DATA
# hermez-network: NO DATA
# polkastarter: DATA GET SUCCESS
# utrust: DATA GET SUCCESS
# shiba-predator: NO DATA
# tomb-shares: NO DATA
# proton: NO DATA
# dodo: NO DATA
# mm-finance: NO DATA
# qredo: DATA GET SUCCESS
# deversifi: NO DATA
# everipedia: NO DATA
# dusk: NO DATA
# alien-worlds: DATA GET SUCCESS
# sologenic: NO DATA
# electroneum: DATA GET SUCCESS
# platon-network: NO DATA
# wonderland: NO DATA
# tomochain: DATA GET SUCCESS
# kishu-inu: NO DATA
# xcad-network: DATA GET SUCCESS
# beefyfinance: NO DATA
# e-money: DATA GET SUCCESS
# torn: NO DATA
# hydra: NO DATA
# fegtoken: NO DATA
# kardiachain: DATA GET SUCCESS
# ageur: NO DATA
# luffy: NO DATA
# mass-vehicle-ledger: DATA GET SUCCESS
# jasmy: NO DATA
# augur: DATA GET SUCCESS
# idex: NO DATA
# gxchain: DATA GET SUCCESS
# yooshi: NO DATA
# star-link: DATA GET SUCCESS
# orionprotocol: DATA GET SUCCESS
# banana-token: NO DATA
# auction: NO DATA
# aioz-network: DATA GET SUCCESS
# itheum: DATA GET SUCCESS
# hunt: NO DATA
# blox: DATA GET SUCCESS
# shapeshift-fox-token: NO DATA
# covalent-new: DATA GET SUCCESS
# cvault-finance: NO DATA
# thundercore: DATA GET SUCCESS
# seedify-fund: NO DATA
# certi-k: DATA GET SUCCESS
# wrappednxm: NO DATA
# hathor: DATA GET SUCCESS
# victoria-vr: DATA GET SUCCESS
# cocos-bcx-token: DATA GET SUCCESS
# aergo: DATA GET SUCCESS
# rmrk: NO DATA
# dola-usd-stablecoin: NO DATA
# badger-dao: NO DATA
# celo-dollar: NO DATA
# alchemix: NO DATA
# safepal: DATA GET SUCCESS
# pond_uniswap: DATA GET SUCCESS
# alpaca-finance: NO DATA
# dvision-network: DATA GET SUCCESS
# adventure-gold: NO DATA
# aurory: DATA GET SUCCESS
# marketpeak: NO DATA
# xmon: NO DATA
# wanchain: DATA GET SUCCESS
# nest-protocol: NO DATA
# clover: DATA GET SUCCESS
# wrapped-centrifuge: NO DATA
# gitcoin: NO DATA
# nominex: NO DATA
# pylon-protocol: NO DATA
# district0x: NO DATA
# defi-pulse-index: NO DATA
# melon: DATA GET SUCCESS
# deapcoin: DATA GET SUCCESS
# efforce: NO DATA
# allianceblock: NO DATA
# automata-network: NO DATA
# neutrino-system-base-token: NO DATA
# unibright: DATA GET SUCCESS
# karura: NO DATA
# klima-dao: NO DATA
# quickswap: NO DATA
# mstable-usd: NO DATA
# lto-network: DATA GET SUCCESS
# concordium: DATA GET SUCCESS
# travala: NO DATA
# unifty: NO DATA
# handshake: DATA GET SUCCESS
# acala-network: DATA GET SUCCESS
# linear: DATA GET SUCCESS
# carry-protocol: DATA GET SUCCESS
# stargaze: NO DATA
# mainframe: DATA GET SUCCESS
# loom-network: DATA GET SUCCESS
# gst: NO DATA
# mwc: NO DATA
# toucan-protocol-base-carbon-tonne: NO DATA
# uquid-coin: NO DATA
# elastos: DATA GET SUCCESS
# keeperdao: NO DATA
# bxmi-token: NO DATA
# gains-network: NO DATA
# alpha-quark-token: NO DATA
# avinoc: NO DATA
# magic: NO DATA
# rakon: NO DATA
# bonfida: DATA GET SUCCESS
# aleph_switcheo: NO DATA
# bitrue-coin: NO DATA
# verasity: DATA GET SUCCESS
# vai-token: NO DATA
# flamingo: NO DATA
# genopets: DATA GET SUCCESS
# socean-staked-sol: NO DATA
# alpine-f-1-team-fan-token: DATA GET SUCCESS
# bitmart-token: DATA GET SUCCESS
# lcx: NO DATA
# swarm: DATA GET SUCCESS
# superrare: NO DATA
# voxies: DATA GET SUCCESS
# komodo: NO DATA
# monacoin: NO DATA
# benqi: DATA GET SUCCESS
# bitcoin-diamond: NO DATA
# gas: NO DATA
# derivadao: NO DATA

# %%
colCategories = ["type", "date", "Price", "ROI", "ATH ROI", "Raise", "Tokens For Sale", "Lock-up", "Min/Max personal Cap"]
roundcolumns = [f"R{i+1} {colCategories[col]}" for i in range(5) for col in range(len(colCategories))]
columns = raw_df.columns.tolist()[:5] + roundcolumns

df = raw_df[columns].copy()

# %%
# write to csv as well as plaintext
df.to_csv("assets_fundraise.csv", index=False)
with open('table_assets_fundraise.txt', 'w') as f:
    f.write(tabulate(df, headers='keys', tablefmt='grid'))
